# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('ggplot')

# %%
HPI_data = pd.read_pickle('../src/fiddy_states_pct.pickle')

# %%
#resampling. http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases
TX1yr = HPI_data['TX'].resample('A').mean()
print(TX1yr.head())
# Out:
# Date
# 1999-12-31     3.781500
# 2000-12-31    10.753894
# 2001-12-31    16.643046
# 2002-12-31    20.867296
# 2003-12-31    24.061076
# Freq: A-DEC, Name: TX, dtype: float64

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((1,1),(0,0))

HPI_data['TX'].plot(ax = ax1, label='Monthly TX HPI')
TX1yr.plot(ax = ax1, label='Yearly TX HPI')
         
plt.legend(loc=4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4">
