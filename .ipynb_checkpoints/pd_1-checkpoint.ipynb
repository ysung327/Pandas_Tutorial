# %%
# virtualenv에서 idle 실행하기.  python -m idlelib

# %%
# %matplotlib notebook
import pandas as pd
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('ggplot')

# %%
start = datetime.datetime(2011,6,11)
end = datetime.datetime.now()

# %%
#pull data from morningstar
df = web.DataReader('XOM','morningstar', start, end)

# %%
print(df.head())
# Out:
#                    Close   High    Low   Open    Volume
# Symbol Date
# XOM    2011-06-13  79.23  80.60  78.84  80.00  17854447
#        2011-06-14  80.38  80.82  79.94  80.05  16444883
#        2011-06-15  78.66  79.89  78.37  79.53  21714147
#        2011-06-16  79.22  79.51  78.33  78.59  19039819
#        2011-06-17  79.02  79.95  78.69  79.85  25468103

# %%
df['High'].plot()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4">
